# %%
from keras.applications.vgg16 import VGG16
import matplotlib.image as mpimg
from keras import backend as K
import matplotlib.pyplot as plt

from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.preprocessing import image

import pandas as pd
from keras.applications.vgg16 import decode_predictions

from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, MaxPool2D, Lambda
from keras.applications.vgg16 import VGG16

import tensorflow.keras.layers

K.clear_session ()

model = Sequential()
model.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu", name="conv2_2"))

#model.add(Lambda(custom_layer1, name="lambda_layer1"))

model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu", name="conv2_4"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu", name="conv2_7"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu", name="conv2_10"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu", name="conv2_13"))
#model.add(Lambda(custom_layer_last, name="lambda_layer_last"))

model.add(MaxPool2D(pool_size=(2,2),strides=(2,2), name="last_max_pool"))

#model.add(Lambda(custom_layer, name="lambda_layer2"))
model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=1000, activation="softmax", name="predictions"))

print("Model created")

# model.compile(loss='categorical_crossentropy', optimizer='sgd',
#               metrics=['accuracy'], experimental_run_tf_function=False)
# print("Model compile")

VGGmodel = VGG16(weights='imagenet', include_top=True)
model.set_weights(VGGmodel.get_weights())
# model = VGG16(weights='imagenet', include_top=True)

model.summary()
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\Hichem\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Hichem\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\Hichem\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Hichem\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %%
import cv2
import os

# folder_Images="ImagentDataset"
folder_Images="classes_50"

# last_fileName=""
# images = []
imagesFileNames = []
for filename in os.listdir(folder_Images):
#     img = cv2.imread(os.path.join(folder_Images,filename))
#     if img is not None:
#         images.append(img)
    imagesFileNames.append(filename)
imagesFileNames.sort()

# %%
import ast
a_file = open("Gimagenet.txt", "r")
string_without_line_breaks = ""
for line in a_file:
    stripped_line = line.rstrip()
    string_without_line_breaks += stripped_line

import re
dict_Classes = ast.literal_eval(re.search('({.+})', string_without_line_breaks).group(0))

# for key, value in dict_Classes.items():
    #print key, value
#     print ('classId', key)
#     print ('value', value)
a_file.close()
# print(dict_Classes)

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

from keras import backend as K
import os
arryWeights_last_After =[]
import scipy as sp

from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.preprocessing import image
from tensorflow.keras import models
            
import tensorflow as tf

from tensorflow.keras.preprocessing import image


for i in range(512):
  arryWeights_last_After.append(i)
# path2 = 'ClassesDataSet_OrigNames'
imgCount_init=0
imgCount = 0
hmpCount = 0
# img_path = 'Mountain_Bike/[image-net.org][27]443691662_09f12b8e37.jpg'
# folder_Images="classes_50/"
# folder_Images="FGSM_Untargeted/"
# folder_Images="PGD_Untargeted/"
# folder_Images="BIM_Untargeted/"
# folder_Images="FGSM_Targeted/"
#folder_Images="BIM_Targeted/"
folder_Images="PGD_Targeted/"

# folder_Images="Prototypes/"

imagesFileNames = []
for filename in os.listdir(folder_Images):
   for imgFileName in os.listdir(folder_Images+filename):
      imgCount_init = 0
      print('img file:', imgFileName)

      img_path = folder_Images+filename + '/'+imgFileName
      img = image.load_img (img_path, target_size=(224, 224))
      x = image.img_to_array (img)
      x = np.expand_dims (x, axis=0)
      x = preprocess_input (x)

      preds = model.predict(x)
      
      classnames = decode_predictions(preds)[0]
#       print(classnames)
      classname = classnames[0][0]
#       print("pred : ", classname)
      known_Id = classname
      element_found=0
      weights_dic_Conv2_13= {}
  #     print ('knownId:', known_Id)
      for key, value in dict_Classes.items():
          if known_Id == key : #classs_Id 
              print("element found")
              element_found=1
              weights_dic_Conv2_13.update(value)
              weights_dic_Conv2_13 = sorted (weights_dic_Conv2_13.items ())
              sorted (weights_dic_Conv2_13, key=lambda kv: kv[1], reverse=True)
              break;
      if element_found==1:
            for i in range(512):
                arryWeights_last_After[i]=0
          ###### For all classes to iconsider only causal features whose CI > 0
            for i in range(512):
              if weights_dic_Conv2_13[i][1][0] > 0:
                  arryWeights_last_After[i] = 1
              else:
                  arryWeights_last_After[i] = 0
            img_path = folder_Images+filename + '/'+imgFileName
            img = image.load_img (img_path, target_size=(224, 224))
            x = image.img_to_array (img)
            x = np.expand_dims (x, axis=0)
            x = preprocess_input (x)

            preds = model.predict(x)
            activatiol_layer = model.get_layer('conv2_13')

            argmax = np.argmax(preds[0])
            output = model.output[:, argmax]
            grads = K.gradients(output, activatiol_layer.output)[0]
            pooled_grads = K.mean(grads, axis=(0, 1, 2))

            
            iterate = K.function([model.input], [pooled_grads, activatiol_layer.output[0]])
            pooled_grads_value, conv_layer_output_value = iterate([x])
            
            # Similar to CAM principle, however we project here only causal features based on arryWeights_last_After
            for i in range(512):
                conv_layer_output_value[:, :, i] *= arryWeights_last_After[i]

            heatmap = np.mean(conv_layer_output_value, axis=-1)
            heatmap = np.maximum(heatmap, 0)
            heatmap /= np.max(heatmap)
            import cv2
            img = cv2.imread(img_path)
            heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
            heatmap = np.uint8(255 * heatmap)
            heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

            hif = .8
            superimposed_img = heatmap * hif + img
            # store results superimposed feature maps on images
            directory_class_imposed = 'superimposed_img_Folder/' + filename
            print("directory_class_imposed:", directory_class_imposed)
            isExist = os.path.exists(directory_class_imposed)
            if not isExist:
               os.makedirs(directory_class_imposed)
            output =  directory_class_imposed + '/' + imgFileName
            print (output)

            cv2.imwrite(output, superimposed_img)


            directory_class_htmp = 'HeatMaps_Folder/' + filename
            isExist = os.path.exists(directory_class_htmp)
            if not isExist:
               os.makedirs(directory_class_htmp)

        #### Added for saving heatmap
            output_heatM = directory_class_htmp + '/' + imgFileName
#                 print ('dest file', 'HeatMaps_Folder/' + filename + '/' + imgFileName)
            cv2.imwrite(output_heatM, heatmap)

            import os
            import shutil

            hmpCount+=1
      imgCount+=1
      imgCount_init+=1
      print("image until now:", imgCount)
# Out:
# img file: ILSVRC2012_val_00009191.JPEG
# element found
# directory_class_imposed: superimposed_img_Folder/0
# superimposed_img_Folder/0/ILSVRC2012_val_00009191.JPEG
# image until now: 1
# img file: ILSVRC2012_val_00010306.JPEG
# element found
# directory_class_imposed: superimposed_img_Folder/0
# superimposed_img_Folder/0/ILSVRC2012_val_00010306.JPEG
# image until now: 2
# img file: ILSVRC2012_val_00016018.JPEG
# element found
# directory_class_imposed: superimposed_img_Folder/0
# superimposed_img_Folder/0/ILSVRC2012_val_00016018.JPEG
# image until now: 3
# img file: ILSVRC2012_val_00024327.JPEG
# element found
# directory_class_imposed: superimposed_img_Folder/0
# superimposed_img_Folder/0/ILSVRC2012_val_00024327.JPEG
# image until now: 4
# img file: ILSVRC2012_val_00026397.JPEG
# element found
# directory_class_imposed: superimposed_img_Folder/0
# superimposed_img_Folder/0/ILSVRC2012_val_00026397.JPEG
# image until now: 5
# img file: ILSVRC2012_val_00030740.JPEG
# element found
# ...

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

from keras import backend as K
import os
arryWeights_last_After =[]
import scipy as sp

from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.preprocessing import image
            
import tensorflow as tf

for i in range(512):
  arryWeights_last_After.append(i)
# path2 = 'ClassesDataSet_OrigNames'
imgCount_init=0
imgCount = 0
hmpCount = 0
# img_path = 'Mountain_Bike/[image-net.org][27]443691662_09f12b8e37.jpg'
for imgFileName in imagesFileNames:
    if imgCount_init==1000:
        K.clear_session()
        model = Sequential()
        model.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
        model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu", name="conv2_2"))

        #model.add(Lambda(custom_layer1, name="lambda_layer1"))

        model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
        model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
        model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu", name="conv2_4"))
        model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
        model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
        model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
        model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu", name="conv2_7"))
        model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
        model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
        model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
        model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu", name="conv2_10"))
        model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
        model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
        model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
        model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu", name="conv2_13"))
        #model.add(Lambda(custom_layer_last, name="lambda_layer_last"))

        model.add(MaxPool2D(pool_size=(2,2),strides=(2,2), name="last_max_pool"))

        #model.add(Lambda(custom_layer, name="lambda_layer2"))
        model.add(Flatten())
        model.add(Dense(units=4096,activation="relu"))
        model.add(Dense(units=4096,activation="relu"))
        model.add(Dense(units=1000, activation="softmax", name="predictions"))

        print("Model created")

        # model.compile(loss='categorical_crossentropy', optimizer='sgd',
        #               metrics=['accuracy'], experimental_run_tf_function=False)
        # print("Model compile")

        VGGmodel = VGG16(weights='imagenet', include_top=True)
        model.set_weights(VGGmodel.get_weights())
        imgCount_init =0
        K.set_learning_phase(0)

    name, boxes = read_content("ILSVRC2012_bbox_val_v3"+ "/" + bbox_FileNames[imgCount])
#      print('box lengt', boxes)
#     print('box lengt', len(boxes))
    if len(boxes)==1:
        numberOfPosFil = 0
#         imgPath = folder_Images + '/' + imgFileName
#         img = image.load_img(imgPath, target_size=(224, 224))
#         x = image.img_to_array (img)
#         x = np.expand_dims (x, axis=0)
#         x = preprocess_input (x)

        known_Id = get_ClassId(folder_Bboxes + '/' + bbox_FileNames[imgCount])

        element_found=0
        weights_dic_Conv2_13= {}
    #     print ('knownId:', known_Id)
        for key, value in dict_Classes.items():
    #         print ('Key:', key)
            if known_Id == key : #classs_Id 
    #             print("element found")
                element_found=1
                weights_dic_Conv2_13.update(value)
                weights_dic_Conv2_13 = sorted (weights_dic_Conv2_13.items ())
                sorted (weights_dic_Conv2_13, key=lambda kv: kv[1], reverse=True)
                break;
    #     weights_dic_Conv2_13.update(
    #     [(301, (0.16395652, 1)), (168, (0.1491422, 1)), (18, (0.14308888, 1)), (134, (0.14197344, 1)), (174, (0.13823563, 1)), (43, (0.118661284, 1)), (331, (0.11572915, 1)), (237, (0.110788584, 1)), (25, (0.09593636, 1)), (293, (0.08435148, 1)), (496, (0.082256556, 1)), (50, (0.08137977, 1)), (71, (0.07686561, 1)), (270, (0.07274145, 1)), (117, (0.07144928, 1)), (205, (0.07136011, 1)), (487, (0.070171595, 1)), (192, (0.06850
 1)), (330, (-0.014287293, 1)), (139, (-0.01451695, 1)), (315, (-0.015471637, 1)), (445, (-0.015775561, 1)), (148, (-0.015843153, 1)), (327, (-0.01694429, 1)), (302, (-0.017455935, 1)), (183, (-0.01799506, 1)), (228, (-0.018740594, 1)), (410, (-0.018928826, 1)), (316, (-0.019136488, 1)), (298, (-0.01964277, 1)), (243, (-0.020198166, 1)), (311, (-0.02167046, 1)), (376, (-0.022851944, 1)), (275, (-0.023623228, 1)), (369, (-0.023893476, 1)), (230, (-0.024080157, 1)), (51, (-0.025204122, 1)), (52, (-0.025243163, 1)), (335, (-0.02541244, 1)), (154, (-0.026719928, 1)), (170, (-0.027140498, 1)), (179, (-0.027948022, 1)), (67, (-0.029270828, 1)), (394, (-0.030921876, 1)), (358, (-0.031933248, 1)), (498, (-0.032136798, 1)), (287, (-0.032897115, 1)), (196, (-0.03356266, 1)), (26, (-0.034562647, 1)), (415, (-0.037610114, 1)), (214, (-0.041793168, 1)), (321, (-0.04206866, 1)), (381, (-0.04308659, 1)), (194, (-0.04385996, 1)), (9, (-0.04771447, 1)), (37, (-0.049587607, 1)), (44, (-0.049598277, 1)), (70, (-0.050301194, 1)), (479, (-0.052226603, 1)), (87, (-0.053698123, 1)), (223, (-0.055024624, 1)), (267, (-0.055607796, 1)), (350, (-0.056448698, 1)), (356, (-0.06127721, 1)), (323, (-0.061362207, 1)), (459, (-0.0620538, 1)), (93, (-0.06386042, 1)), (41, (-0.07631606, 1)), (314, (-0.07697344, 1)), (61, (-0.08439565, 1)), (418, (-0.10121894, 1)), (354, (-0.10642445, 1)), (24, (-0.11001116, 1)), (475, (-0.12109661, 1)), (209, (-0.13021761, 1)), (227, (-0.13600117, 1)), (221, (-0.15241575, 1)), (152, (-0.17205942, 1)), (59, (-0.1963982, 1)), (333, (-0.20827669, 1)), (45, (-0.21776813, 1)), (120, (-0.269678, 1))]

    #     )
    #     weights_dic_Conv2_13 = sorted (weights_dic_Conv2_13.items ())
    #     sorted (weights_dic_Conv2_13, key=lambda kv: kv[1], reverse=True)
        if element_found==1:
            for i in range(512):
              arryWeights_last_After[i]=0
            ###### For all classes to increase probability and for object localization
            for i in range(512):
                if weights_dic_Conv2_13[i][1][0] > 0:
                    arryWeights_last_After[i] = 1
                    #numberOfPosFil+=1
            #         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
                else:
                    arryWeights_last_After[i] = 0
    #                 print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
            ###### For all classes to increase probability and for object localization        

            # ############################### #using resp function
            # print('prob thresh', weights_dic_Conv2_13_sorted[2][1][0])
    #         weights_dic_Conv2_13_sorted = sorted (weights_dic_Conv2_13, key=lambda kv: kv[1], reverse=True)
    #         arryWeights_last_After = respFilters(weights_dic_Conv2_13_sorted[2][1][0], weights_dic_Conv2_13)
            # ############################### #using resp function

            # ############################### #using filters order
            # print('prob thresh', weights_dic_Conv2_13_sorted[2][1][0])        
#             weights_dic_Conv2_13_sorted = sorted (weights_dic_Conv2_13, key=lambda kv: kv[1], reverse=True)
#             print('posit filt', numberOfPosFil)
#     #         for i in range (numberOfPosFil//10):
#             for i in range (int(round(numberOfPosFil * 9/10))):
#                 arryWeights_last_After[weights_dic_Conv2_13_sorted[i][0]]= 1
            # ############################### #using resp function

            # for i in range(len(arryWeights_last_After)):
            #     print ('filter' + str(i)+ ' value becomes', arryWeights_last_After[i])

            # img_path = 'Tiger_cat/358755626_6af0a93729.png'
            img_path = folder_Images + '/' + imgFileName
            img = mpimg.imread (img_path)

#             activatiol_layer = model.get_layer('conv2_13')

    #         new_model = Model(inputs=model.input, outputs=activatiol_layer.output)
            #get the feature map weights
    #         final_dense = model.get_layer('predictions')
    #         W = final_dense.get_weights()[0]

            img = image.load_img (img_path, target_size=(224, 224))
            x = image.img_to_array (img)
            x = np.expand_dims (x, axis=0)
            x = preprocess_input (x)

            activatiol_layer = model.get_layer('conv2_13')
#             activatiol_layer = model.get_layer('block5_conv3')
            
            #print('layer_name:', activatiol_layer.name)
    #         filters= activatiol_layer.get_weights()[0]
    #         num_filters_Layer = len (filters[0, 0, 0, :])

    #         new_model = Model(inputs=model.input, outputs=activatiol_layer.output)
        
            #with tf.GradientTape() as tape:
            #    preds = model(x, training=False)
            #preds = model(x)
            preds = model.predict_on_batch(x)
#             preds = model.predict(x)
    #         fmaps = preds[0] 

        #     classnames = decode_predictions(preds)[0]
        #     #print(classnames)
        #     classname = classnames[0][1]

            argmax = np.argmax(preds[0])
            output = model.output[:, argmax]
            grads = K.gradients(output, activatiol_layer.output)[0]
            pooled_grads = K.mean(grads, axis=(0, 1, 2))
            iterate = K.function([model.input], [pooled_grads, activatiol_layer.output[0]])
            pooled_grads_value, conv_layer_output_value = iterate([x])

            for i in range(512):
                conv_layer_output_value[:, :, i] *= arryWeights_last_After[i]

            #for i in range(512):
            #    fmaps[:, :, i] *= w[i]
            heatmap = np.mean(conv_layer_output_value, axis=-1)
            heatmap = np.maximum(heatmap, 0)
            heatmap /= np.max(heatmap)
            import cv2
            img = cv2.imread(img_path)
            heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
            heatmap = np.uint8(255 * heatmap)
            heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

            hif = .8
            superimposed_img = heatmap * hif + img
            output = 'superimposed_img_Folder/' + imagesFileNames[imgCount]
            cv2.imwrite(output, superimposed_img)
    #         img=mpimg.imread(output)
            #plt.imshow(img)
            #plt.axis('on')

            #### Added for saving heatmap
            output_heatM = 'HeatMaps_Folder/' + imagesFileNames[imgCount]
            cv2.imwrite(output_heatM, heatmap)
    #         img_hM=mpimg.imread(output_heatM)
            #plt.imshow(img_hM)
            #### Added for saving heatmap
            #### move the analyzd image to images_already
            import os
            import shutil

            #os.rename(imgPath, "Images_Already_heatM/" + imagesFileNames[imgCount])
    #         shutil.move(imgPath, "Images_Already_heatM/" +  imagesFileNames[imgCount])
            #os.replace(imgPath, "Ima"ImagentDataset" + "/" + ges_Already_heatM/" + imagesFileNames[imgCount])
            #### move the analyzd image to images_already
            hmpCount+=1
    #         print("heatmap until now:", hmpCount)
    else:
        os.remove("ImagentDataset" + "/" + imgFileName)
        os.remove("ILSVRC2012_bbox_val_v3"+ "/" + bbox_FileNames[imgCount])
    imgCount+=1
    imgCount_init+=1
    print("image until now:", imgCount)
# weights_dic_Conv2_10 = sorted (weights_dic_Conv2_10.items ())
# weights_dic_Conv2_7 = sorted (weights_dic_Conv2_7.items ())
# weights_dic_Conv2_4 = sorted (weights_dic_Conv2_4.items ())
# weights_dic_Conv2_2 = sorted (weights_dic_Conv2_2.items ())
# Out:
# image until now: 1
# image until now: 2
# image until now: 3
# image until now: 4
# image until now: 5
# image until now: 6
# image until now: 7
# image until now: 8
# image until now: 9
# image until now: 10
# image until now: 11
# image until now: 12
# image until now: 13
# image until now: 14
# image until now: 15
# image until now: 16
# image until now: 17
# image until now: 18
# image until now: 19
# image until now: 20
# image until now: 21
# image until now: 22
# image until now: 23
# image until now: 24
# image until now: 25
# image until now: 26
# image until now: 27
# image until now: 28
# image until now: 29
# image until now: 30
# image until now: 31
# image until now: 32
# image until now: 33
# image until now: 34
# image until now: 35
# image until now: 36
# image until now: 37
# image until now: 38
# image until now: 39
# image until now: 40
# image until now: 41
# image until now: 42
# image until now: 43
# image until now: 44
# image until now: 45
# ...

# %%
# def respFilters(ProbThersh, filters_list):
#     arryResps =[]
#     for i in range(512):
#       arryResps.append(i)
#     for i in range(512):
#       arryResps[i]=0
#     for i in range(len(filters_list)):
#         if(filters_list[i][1][0])>= ProbThersh:
#             arryResps[i]=1
#         elif (filters_list[i][1][0])<= 0:
#             arryResps[i]=0
#         else:
#             prob = filters_list[i][1][0]
#             w=0
#             for j in range(len(filters_list)):
#                 if(filters_list[j][1][0])>=0 and (filters_list[j][1][0])<ProbThersh and j!=i:
#                     prob = prob + filters_list[j][1][0]
#                     w = w+1
#                     if(prob>= ProbThersh):
#                        arryResps[i]=1/(w+1)
#                        break             
#     return arryResps

# %%
# arryWeights_last_After = []
# weights_dic_Conv2_13_sorted = sorted (weights_dic_Conv2_13, key=lambda kv: kv[1], reverse=True)
# # arryWeights_last_After = respFilters(0.17, weights_dic_Conv2_13_sorted)
# arryWeights_last_After.sort(reverse=True)
# # for i in range(512):
# #     print('Resp of filter: ', weights_dic_Conv2_13_sorted[i][0], 'is ', arryWeights_last_After[i])

# %%
arryWeights_last_After =[]
for i in range(512):
  arryWeights_last_After.append(i)
for i in range(512):
  arryWeights_last_After[i]=1
positifFilter = 0

for i in range(len(weights_dic_Conv2_13)):
############################# Macaw
#     if weights_dic_Conv2_13[i][1][0] < 0.026:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
        
#     #  ############################# Ice bear
#     if weights_dic_Conv2_13[i][1][0] < 0.004:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     #  ############################# Electric guitar   Positive
#     if weights_dic_Conv2_13[i][1][0] < 0.5:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# ############################# Egyptian Cat / Boxer    Original test
#     if weights_dic_Conv2_13[i][1][0] >= -11:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] > -5 and weights_dic_Conv2_13[i][1][0] < -1:
# #         arryWeights_last_After[i] = 0.0
# #         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] <= -11:
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

# ############################# Egyptian Cat
#     if weights_dic_Conv2_13[i][1][0] > -1:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] > -3 and weights_dic_Conv2_13[i][1][0] <= -1:
# #         arryWeights_last_After[i] = 0.25
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] > -5 and weights_dic_Conv2_13[i][1][0] <= -3:
#         arryWeights_last_After[i] = 0.5
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -5 and weights_dic_Conv2_13[i][1][0] >= -9:
#         arryWeights_last_After[i] = 0.75
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] <= -9:
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
        
#  ############################# Waching machine  
#     if weights_dic_Conv2_13[i][1][0] >= -0.014:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.014 and weights_dic_Conv2_13[i][1][0] > -0.04:
#         arryWeights_last_After[i] = 0.0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.04 :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])


#  ############################# Electric guitar   
#     if weights_dic_Conv2_13[i][1][0] >= -0.034:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.034 :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

# #  ############################# Electric guitar   Positive
#     if weights_dic_Conv2_13[i][1][0] < 0.07:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

 ############################# Hummingbird   
#     if weights_dic_Conv2_13[i][1][0] >= -0.0011:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.0011 :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

#     if weights_dic_Conv2_13[i][1][0] >= -0.0019:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.0019:
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])


 ############################# Hummingbird  Positive  
# #     [(418, (0.017570019, 1)), (41, (0.014584243, 1)), (455, (0.012359321, 1)), (397, (0.012108624, 1)), (214, (0.0076738, 1)), (497
#     if weights_dic_Conv2_13[i][1][0] < 0.012:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

        
#  ############################# Gazelle Deer   Original
#     if weights_dic_Conv2_13[i][1][0] >= -0.011:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.011 :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

#  ############################# Gazelle Deer   Positive
#     if weights_dic_Conv2_13[i][1][0] < 0.11:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

#  ############################# Gazelle Deer   no 5
#     if weights_dic_Conv2_13[i][1][0] >= -0.011:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.011:
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
        
# #  ############################# Umbrella   2
#     if weights_dic_Conv2_13[i][1][0] >= -0.00027:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.00027:
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

# #  ############################# Umbrella   1
#     if weights_dic_Conv2_13[i][1][0] >= -0.0065:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.0065 :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])


# # #  ############################# Umbrella   1 Positive
#     if weights_dic_Conv2_13[i][1][0] < 0.02:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

# #  ############################# Umbrella   1 Positive_2
#     if weights_dic_Conv2_13[i][1][0] < 0.17:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

# #  ############################# Mountain Bike   
#     if weights_dic_Conv2_13[i][1][0] >= -0.021:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.021 :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

#  ############################# Mountain Bike   
#     if weights_dic_Conv2_13[i][1][0] >= -0.021:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.021 :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

#  ############################# Mountain Bike Positive 
#     if weights_dic_Conv2_13[i][1][0] < 0.21:
# ###     if weights_dic_Conv2_13[i][1][0] <=0: ### just for test
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
# #         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

        
 ############################# Tiger   
#     if weights_dic_Conv2_13[i][1][0] >= -0.050: # -0.024
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -0.050: #-0.024
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

#  ############################# Tiger Positive
#     if weights_dic_Conv2_13[i][1][0] < 0.17: # -0.024
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
# #         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

#  ############################# Tabby
#     if weights_dic_Conv2_13[i][1][0] < 0.046: # -0.024
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
# #         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

# ############################# Egyptian Cat    
        
#   if weights_dic_Conv2_13[i][1][0] >= -0.00001:
#     arryWeights_last_After[i] = 0
#     print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#   elif weights_dic_Conv2_13[i][1][0] < -0.00001:
#     arryWeights_last_After[i] = 1
#     print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#   else:
#     arryWeights_last_After[i] = 0.5
#     print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i]) 
#   elif weights_dic_Conv2_13[i][1][0] < 0 and weights_dic_Conv2_13[i][1][0]> -0.002:
#     arryWeights_last_After[i] = 0.5
#     print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#   elif weights_dic_Conv2_13[i][1][0]< -0.002:
#     arryWeights_last_After[i] = 1
#     print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#   else if weights_dic_Conv2_13[i][1][0] < -0.01:
#     arryWeights_last_After[i] = 0.5
#     print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#   # if weights_dic_Conv2_13[i][1][0] >= 5:
#   #   arryWeights_last_After[i] = -5
#   #   print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])


#   if weights_dic_Conv2_13[i][1][0] >= -1 and weights_dic_Conv2_13[i][1][0] < 0:
#     #arryWeights_last_After[i] = 1
#     arryWeights_last_After[i] = 0
#     print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

# ############################# Coffe mug

#     if weights_dic_Conv2_13[i][1][0] > -1:
#         arryWeights_last_After[i] = 0
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -1 and weights_dic_Conv2_13[i][1][0] >= -5:
#         arryWeights_last_After[i] = 0 #1/10 
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -5 and weights_dic_Conv2_13[i][1][0] >= -10:
#         arryWeights_last_After[i] = 0 #1/5 #-1*(weights_dic_Conv2_13[i][0])
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -10:
#         arryWeights_last_After[i] = 1 #-1*(weights_dic_Conv2_13[i][0])
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         #arryWeights_last_After[i] *= -1*(weights_dic_sort[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])


############################# Coffe mug better

#     if weights_dic_Conv2_13[i][1][0] > -3:
#         arryWeights_last_After[i] = 0
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < -5:
#         arryWeights_last_After[i] = 1 
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
        
####### For all classes to increase probability
#     if weights_dic_Conv2_13[i][1][0] >= 0:
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     elif weights_dic_Conv2_13[i][1][0] < 0:
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

#  ############################# Panda
#     if weights_dic_Conv2_13[i][1][0] < 0.37: 
#         arryWeights_last_After[i] = 0
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# #     elif weights_dic_Conv2_13[i][1][0] < -0.01 and weights_dic_Conv2_13[i][1][0] > -0.2:
# #         arryWeights_last_After[i] = 0.1
# #         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else :
#         arryWeights_last_After[i] = 1
#         print('filter value ',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])


#################################################"" Perturbation section

############################# Grey_owl

#     if weights_dic_Conv2_13[i][1][0] >= 0.000133:
#         arryWeights_last_After[i] = 1
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else:
#         arryWeights_last_After[i] = 0
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
        
############################# Dowitcher
#     if weights_dic_Conv2_13[i][1][0] >= 0:
# #     if weights_dic_Conv2_13[i][1][0] >= 0.0023:
#         arryWeights_last_After[i] = 1
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else:
#         arryWeights_last_After[i] = 0
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
        

    
############################# Bullet_Train

#     if weights_dic_Conv2_13[i][1][0] >= 0.016:
#         arryWeights_last_After[i] = 1
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else:
#         arryWeights_last_After[i] = 0
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])


############################# Grand_Piano
# #     if weights_dic_Conv2_13[i][1][0] >= 0:
#     if weights_dic_Conv2_13[i][1][0] >= 0.00023:
#         arryWeights_last_After[i] = 1
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else:
#         arryWeights_last_After[i] = 0
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])


############################# Killer_Whale

#     if weights_dic_Conv2_13[i][1][0] >= 0.073:
#         arryWeights_last_After[i] = 1
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else:
#         arryWeights_last_After[i] = 0
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

############################# Book jacket

#     if weights_dic_Conv2_13[i][1][0] >= 0.10:
#         arryWeights_last_After[i] = 1
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else:
#         arryWeights_last_After[i] = 0
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])

############################# Kit

#     if weights_dic_Conv2_13[i][1][0] >= 0.12:
#         arryWeights_last_After[i] = 1
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else:
#         arryWeights_last_After[i] = 0
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])


############################# Ice_lolly

#     if weights_dic_Conv2_13[i][1][0] >= 0.12:
#         arryWeights_last_After[i] = 1
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
#     else:
#         arryWeights_last_After[i] = 0
#         #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
#         print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])


# def custom_layer_last(tensor):
#     print ('tesnor values :', tensor[0][0])
#     return tensor * arryWeights_last_After[i]
    #return tensor * 1
#############################################################
####### For all classes to increase probability and for object localization
    if weights_dic_Conv2_13[i][1][0] > 0:
        arryWeights_last_After[i] = 1
        positifFilter+=1
        #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
        print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
    else:
        arryWeights_last_After[i] = 0
        #arryWeights_last_After[i] = -1*(weights_dic_Conv2_13[i][1][0])
        print('filter value',i, weights_dic_Conv2_13[i][1][0], 'becomes', arryWeights_last_After[i])
# Out:
# filter value 0 -0.0016832352 becomes 0
# filter value 1 -0.0016134381 becomes 0
# filter value 2 2.0503998e-05 becomes 1
# filter value 3 -0.00039821863 becomes 0
# filter value 4 -0.0011806488 becomes 0
# filter value 5 -7.534027e-05 becomes 0
# filter value 6 0.0404979 becomes 1
# filter value 7 0.0 becomes 0
# filter value 8 0.031165004 becomes 1
# filter value 9 -0.04771447 becomes 0
# filter value 10 0.0 becomes 0
# filter value 11 -0.0028844476 becomes 0
# filter value 12 0.0050230026 becomes 1
# filter value 13 0.0 becomes 0
# filter value 14 0.0361979 becomes 1
# filter value 15 0.03287548 becomes 1
# filter value 16 0.06482023 becomes 1
# filter value 17 8.0645084e-05 becomes 1
# filter value 18 0.14308888 becomes 1
# filter value 19 -0.011816502 becomes 0
# filter value 20 0.00049728155 becomes 1
# filter value 21 0.0 becomes 0
# filter value 22 0.0 becomes 0
# filter value 23 -0.010240138 becomes 0
# filter value 24 -0.11001116 becomes 0
# ...

# %% [markdown]
# ###  THis cell to delete negative filters and see the effect of calass pred prob

# %%
# ##### Only is ised with keras surgeon, if using Lambda delete this cell, and use the cells bewlo
# from kerassurgeon import identify
# from kerassurgeon.operations import delete_channels
# from kerassurgeon import utils
# from kerassurgeon import Surgeon

# #surg_model = model.model
# layer2 = model.get_layer('conv2_13')
# filters2= layer2.get_weights()[0]
# #total_filters = [filters1, filters1]
# num_filters_Layer2 = len (filters2[0, 0, 0, :])
# surgeon = Surgeon (model)
# ############Bird
# #channels_Resp_L2 = [446, 148, 89, 188, 144, 150, 350, 354, 169, 49, 436, 447, 343, 349, 49]
# ############ Truck
# # channels_Resp_L2 = [323, 425, 79, 414, 49, 230, 84, 30, 485, 370, 432, 244, 60, 72, 216,     115, 178, 473, 440, 217, 19]
# ############ Plain
# #channels_Resp_L2 = [409, 299, 13, 269, 484, 320, 47, 126, 161, 101, 398, 68, 397, 344, 489,     309]
# ############ Deer
# #channels_Resp_L2 = [143, 433, 298, 134, 10, 271, 217, 201, 262, 120, 146, 425, 68, 160, 184, 185]
# ############ Boat
# #channels_Resp_L2 = [445, 319, 377, 392, 61, 66, 94, 506, 75, 427, 295, 442, 124]
# channelsToDelete_L2=[]
# for i in range(512):
#     #if i not in channels_Resp_L2:
#     if arryWeights_last_After[i] == 0:
#         channelsToDelete_L2.append(i)
# surgeon.add_job ('delete_channels', layer2,
#                  channels=channelsToDelete_L2)

# model = surgeon.operate ()
# model.compile (optimizer='adam',
#                      loss='categorical_crossentropy',
#                      metrics=['accuracy'])

# # loss_after = model.model.evaluate (x_test, y_test, verbose=0)
# # print ('after model loss:', loss_after, '\n')

# %%
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.preprocessing import image

print('number of pos filters:', positifFilter)
# img_path = 'Tiger_cat/358755626_6af0a93729.png'
img_path = 'ice_lolly/ILSVRC2012_val_00048151.jpeg'
img = mpimg.imread (img_path)
plt.imshow (img)

#From keras_vis VGG CAM:
#y default, if penultimate_layer_idx is not defined,
# it searches for the nearest pre layer. For our architecture, that would be the block5_pool layer after all
# the Conv layers. Here is the model summary for reference.

#activatiol_layer = model.get_layer('last_max_pool')
#activatiol_layer = model.get_layer('conv2_13')
activatiol_layer = model.get_layer('conv2_13')
 
new_model = Model(inputs=model.input, outputs=activatiol_layer.output)
#get the feature map weights
final_dense = model.get_layer('predictions')
W = final_dense.get_weights()[0]

import scipy as sp

img = image.load_img (img_path, target_size=(224, 224))
x = image.img_to_array (img)
x = np.expand_dims (x, axis=0)
x = preprocess_input (x)
# Out:
# number of pos filters: 222

# %%
activatiol_layer = model.get_layer('conv2_13')
print('layer_name:', activatiol_layer.name)
filters= activatiol_layer.get_weights()[0]
num_filters_Layer = len (filters[0, 0, 0, :])

new_model = Model(inputs=model.input, outputs=activatiol_layer.output)
preds = model.predict(x)
predictions = pd.DataFrame(decode_predictions(preds, top=5)[0],columns=['col1','category','probability']).iloc[:,1:]
print('PREDICTION:',predictions.loc[0,'category'])
import seaborn as sns
f = sns.barplot(x='probability',y='category',data=predictions,color="red")
sns.set_style(style='white')
f.grid(False)
f.spines["top"].set_visible(False)
f.spines["right"].set_visible(False)
f.spines["bottom"].set_visible(False)
f.spines["left"].set_visible(False)
f.set_title('Top 5 Predictions:')
# Out:
# layer_name: conv2_13
# PREDICTION: laptop
# Text(0.5, 1.0, 'Top 5 Predictions:')

# %%
#new_model = delete_channels (new_model, activatiol_layer, filtersToDelete, copy=True)
#model = delete_channels (model, activatiol_layer, filtersToDelete, copy=True)

fmaps = new_model.predict(x)[0] # 7 X 7 X 2048 (Resnet) (grads)
preds = model.predict(x)
classnames = decode_predictions(preds)[0]
#print(classnames)
classname = classnames[0][1]

# %%
argmax = np.argmax(preds[0])
output = model.output[:, argmax]
grads = K.gradients(output, activatiol_layer.output)[0]
pooled_grads = K.mean(grads, axis=(0, 1, 2))
iterate = K.function([model.input], [pooled_grads, activatiol_layer.output[0]])
pooled_grads_value, conv_layer_output_value = iterate([x])

pred = np.argmax (preds[0])

heatmap = np.mean(fmaps, axis=-1)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
import cv2
img = cv2.imread(img_path)
heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
hif = .8
superimposed_img = heatmap * hif + img
output = 'output.jpeg'
cv2.imwrite(output, superimposed_img)
img=mpimg.imread(output)
plt.imshow(img)
plt.axis('off')
#plt.show()
# Out:
# (-0.5, 499.5, 374.5, -0.5)

# %%
argmax = np.argmax(preds[0])
output = model.output[:, argmax]
grads = K.gradients(output, activatiol_layer.output)[0]
pooled_grads = K.mean(grads, axis=(0, 1, 2))
iterate = K.function([model.input], [pooled_grads, activatiol_layer.output[0]])
pooled_grads_value, conv_layer_output_value = iterate([x])

for i in range(512):
    conv_layer_output_value[:, :, i] *= arryWeights_last_After[i]

#for i in range(512):
#    fmaps[:, :, i] *= w[i]
heatmap = np.mean(conv_layer_output_value, axis=-1)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
import cv2
img = cv2.imread(img_path)
heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

hif = .8
superimposed_img = heatmap * hif + img
output = 'output.jpeg'
cv2.imwrite(output, superimposed_img)
img=mpimg.imread(output)
plt.imshow(img)
plt.axis('on')
# Out:
# (-0.5, 499.5, 374.5, -0.5)

# %%
#### Added for saving heatmap
output_heatM = 'output_heatM.jpeg'
cv2.imwrite(output_heatM, heatmap)
img_hM=mpimg.imread(output_heatM)
plt.imshow(img_hM)
#### Added for saving heatmap
