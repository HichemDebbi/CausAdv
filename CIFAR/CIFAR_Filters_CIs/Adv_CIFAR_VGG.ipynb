# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import optimizers
import numpy as np
from keras.layers.core import Lambda
from keras import backend as K
from keras import regularizers

import cv2
import sklearn.metrics as metrics


arryWeights_last = []

class cifar10vgg:
    arryWeights_last = []
    for i in range (512):
        arryWeights_last.append (i)

    for i in range (512):
        arryWeights_last[i] = 1
    # add a lambda layer for deactivating filters
    def custom_layer_last(self, tensor):
        return tensor * self.arryWeights_last

    def __init__(self,train=False):
        #Sequential.__init__ (self)
        self.num_classes = 10
        self.weight_decay = 0.0005
        self.x_shape = [32,32,3]
        self.model = self.build_model()
        if train:
             self.model = self.train(self.model)
        else:
            self.model.load_weights('cifar10vgg.h5')

    def build_model(self):
        # Build the network of vgg for 10 classes with massive dropout and weight decay as described in the paper.
        model = Sequential()
        weight_decay = self.weight_decay

        model.add(Conv2D(64, (3, 3), padding='same',
                         input_shape=self.x_shape,kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))

        model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))


        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))


        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay), name="conv2d_13"))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Lambda(self.custom_layer_last, name="lambda_layer_last"))

        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.5))

        model.add(Flatten())
        model.add(Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Dropout(0.5))
        model.add(Dense(self.num_classes))
        model.add(Activation('softmax'))
        #model.summary()
        return model


    def normalize(self,X_train,X_test):
        #this function normalize inputs for zero mean and unit variance
        # it is used when training a model.
        # Input: training set and test set
        # Output: normalized training set and test set according to the trianing set statistics.
        mean = np.mean(X_train,axis=(0,1,2,3))
        std = np.std(X_train, axis=(0, 1, 2, 3))
        X_train = (X_train-mean)/(std+1e-7)
        X_test = (X_test-mean)/(std+1e-7)
        return X_train, X_test

    def normalize_production(self,x):  
        #this function is used to normalize instances in production according to saved training set statistics
        # Input: X - a training set
        # Output X - a normalized training set according to normalization constants.

        #these values produced during first training and are general for the standard cifar10 training set normalization
        mean = 120.707
        std = 64.15
        return (x-mean)/(std+1e-7)

    def predict(self,x,normalize=True,batch_size=50):
        if normalize:
            x = self.normalize_production(x)
        return self.model.predict(x,batch_size)
    def summary(self):
      print(self.model.summary())

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Colab/Adversail/CIFAR/'
# !ls '/content/drive/My Drive/Colab/Adversail/CIFAR/'
# Out:
# /content/drive/My Drive/Colab/Adversail/CIFAR
# Adv_CIFAR_VGG.ipynb  cifar10vgg.h5  Filt_Resp_CIFAR_BIM.txt  PGD_10
# BIM_10		     FGSM_10	    Filt_Resp_CIFAR_PGD.txt

# %%
# !ls 'PGD_10/5'
# Out:
# 1230.png  128.png  1339.png  1355.png  1385.png  1389.png  1506.png  1536.png

# %%
import tensorflow as tf
# from keras.applications import VGG16
# from vis.utils import utils

from keras.utils import np_utils


from keras import activations
from keras.models import Sequential, Model, load_model

model = cifar10vgg ()
# model.summary()

# %%
print(model.model.layers[(51)].name)
# Out:
# lambda_layer_last

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import optimizers
import numpy as np
from keras.layers.core import Lambda
from keras import backend as K
from keras import regularizers

import cv2
import sklearn.metrics as metrics

from keras.utils import np_utils

from keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

y_train = keras.utils.np_utils.to_categorical(y_train, 10)
y_test = keras.utils.np_utils.to_categorical(y_test, 10)

# %%
predicted_x = model.predict (x_test)
residuals = np.argmax (predicted_x, 1) != np.argmax (y_test, 1)
loss = sum (residuals) / len (residuals)
print ("the validation 0/1 loss is: ", loss)
# print ("accu is: ", 1- loss)
orig_acc = 1 - loss
print ("origin accu is: ", 1- loss)
# original_loss = model.evaluate(x_test, y_test, verbose=0)
# print('original model loss:', original_loss, '\n')
# Out:
# 200/200 [==============================] - 10s 10ms/step
# the validation 0/1 loss is:  0.0641
# origin accu is:  0.9359

# %%
import cv2
import os
from shutil import copyfile
from pathlib import Path


folder = "PGD_10/"


last_fileName=""
#images = []
imagesFileNames = []

for i in range(5, 10):
    # for img in os.listdir(folder+filename):
  imagesFileNames.append(str(i))

    # print(filename)
# imagesFileNames.sort()
print(len(imagesFileNames))
# Out:
# 5

# %%
imagesFileNames[0]
# Out:
# '2'

# %%
from keras.engine import training
import re
from keras.models import Model

def insert_intermediate_layer_in_keras(model, layer_id, new_layer):
    from keras.models import Model
    layers = [l for l in model.layers]

    x = layers[0].output
    for i in range(1, len(layers)):
        if i == layer_id:
            x = new_layer(x)
        x = layers[i](x)
    new_model = Model(layers[0].input, x)
    return new_model

# %% [markdown]
# # This code for computing the CIs of every image and storing it in a dioctionnary, the example here is Filt_Resp_CIFAR_PGD

# %%
from keras.layers import Lambda
from keras import backend as K
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, MaxPool2D

from tensorflow.keras.preprocessing import image


weights_dic = {}

imgCount = 0
indexImg=0
# img_path = 'Mountain_Bike/[image-net.org][27]443691662_09f12b8e37.jpg'
for imgFileName in imagesFileNames:
    imgs_by_class = len(os.listdir(folder + imagesFileNames[indexImg]))
    print('length_folder:', imgs_by_class)
    print('--------------------------------------------------------------------')
    for k in range(imgs_by_class):
      dctOfAllDictionClasses = {}
      imgPath = folder + imagesFileNames[indexImg] + "/" + os.listdir(folder + imagesFileNames[indexImg])[k]
      print('imgPath : ' , imgPath)
      string_index = os.listdir(folder + imagesFileNames[indexImg])[k].replace('.png','')
      index =  int(string_index)  
      img = image.load_img(imgPath, target_size=(32, 32))
      x = image.img_to_array (img)
      x = np.expand_dims (x, axis=0)
      # x = preprocess_input (x)

      # preds = model.predict(x)
      probs = model.predict (x)
      # probs = model.predict (x_test[np.newaxis, index])
      prediction = probs.argmax (axis=1)
      probOrig = probs.max ()
    # print(prediction)
    #origin_pred = prediction[1]*100
      print ('%s (%.2f%%)' % (prediction, probOrig * 100))
        #print('%s pred before (%.2f%%)' % (prediction[0], prediction[1]*100))
      print ("[INFO] Predicted: {}, Actual: {}".format (
              prediction[0], np.argmax (y_test[index])))
        
      from keras.layers import Lambda
      weights_dic = {}

      import time
      start_time = time.time()
      for i in range(512):
          print ('filt{}'.format (i))
          # arryWeights_last_After[i]=0
          # def custom_layer_last(tensor):
          #   return tensor * arryWeights_last_After[i]
          filt = i
          # preds = new_model.predict(x)
        # #############################################################

          model.arryWeights_last[i]=0
            #arryWeights_last[j]=0
          model = cifar10vgg ()
        # #############################################################

          probs = model.predict(x)
          prediction = probs.argmax (axis=1)
          probNew = probs.max ()

          print ('%s (%.2f%%)' % (prediction, probNew * 100))
          print ("[INFO] Predicted new: {}, Actual: {}".format (
                prediction[0], np.argmax (y_test[index])))
          print ("difference: ", probOrig - probNew)
          tuple = (probOrig - probNew), 1
          #weights_dic[filt] = original_loss[1] - loss[1]  # prob
          weights_dic[filt] = tuple
          # for i in range(512):
          model.arryWeights_last[i]=1
      weights_dic_sort = sorted (weights_dic.items (), key=lambda kv: kv[1], reverse=True)

      print("--- %s seconds ---" % (time.time() - start_time))
      originalName=imgFileName + '__' + os.listdir(folder + imagesFileNames[indexImg])[k]+'_as_'+ str(prediction[0])
      pairKeyValue = { originalName: weights_dic_sort}

      dctOfAllDictionClasses = {}
      dctOfAllDictionClasses.update(pairKeyValue)
      print('pair ley:', pairKeyValue)
      import json

      with open('Filt_Resp_CIFAR_PGD.txt', 'a+') as fout:
          fout.write("\n" + str(dctOfAllDictionClasses) + "\n")
      imgCount+=1
    indexImg+=1
# Out:
# length_folder: 7
# --------------------------------------------------------------------
# imgPath :  PGD_10/8/1721.png
# 1/1 [==============================] - 0s 41ms/step
# [0] (53.06%)
# [INFO] Predicted: 0, Actual: 8
# filt0
# 1/1 [==============================] - 0s 358ms/step
# [0] (53.27%)
# [INFO] Predicted new: 0, Actual: 8
# difference:  -0.0021478534
# filt1
# 1/1 [==============================] - 0s 304ms/step
# [0] (53.47%)
# [INFO] Predicted new: 0, Actual: 8
# difference:  -0.004055202
# filt2
# 1/1 [==============================] - 0s 329ms/step
# [0] (53.65%)
# [INFO] Predicted new: 0, Actual: 8
# difference:  -0.005926609
# filt3
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd6035b11f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 311ms/step
# [0] (52.91%)
# [INFO] Predicted new: 0, Actual: 8
# difference:  0.0015459061
# filt4
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd6034d2310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Streaming output truncated to the last 5000 lines.
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0013625622
# filt436
# 1/1 [==============================] - 0s 330ms/step
# [8] (93.07%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0010607839
# filt437
# 1/1 [==============================] - 0s 331ms/step
# [8] (93.06%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0010027289
# filt438
# 1/1 [==============================] - 0s 311ms/step
# [8] (93.08%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0011898875
# filt439
# 1/1 [==============================] - 0s 318ms/step
# [8] (92.92%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.00039935112
# filt440
# 1/1 [==============================] - 0s 318ms/step
# [8] (93.15%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0018616915
# filt441
# 1/1 [==============================] - 0s 340ms/step
# [8] (93.04%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0007442832
# filt442
# 1/1 [==============================] - 0s 497ms/step
# [8] (92.87%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.000944674
# filt443
# 1/1 [==============================] - 0s 487ms/step
# [8] (92.97%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -4.2378902e-05
# filt444
# 1/1 [==============================] - 0s 318ms/step
# [8] (93.16%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0019538403
# filt445
# 1/1 [==============================] - 0s 310ms/step
# [8] (93.13%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0017073154
# filt446
# 1/1 [==============================] - 0s 330ms/step
# [8] (93.08%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0012277961
# filt447
# 1/1 [==============================] - 0s 327ms/step
# [8] (92.96%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  5.3167343e-05
# filt448
# 1/1 [==============================] - 0s 318ms/step
# [8] (93.07%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0011208057
# filt449
# 1/1 [==============================] - 0s 317ms/step
# [8] (93.10%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0013831258
# filt450
# 1/1 [==============================] - 0s 323ms/step
# [8] (92.87%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.00096452236
# filt451
# 1/1 [==============================] - 0s 322ms/step
# [8] (93.13%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0016551614
# filt452
# 1/1 [==============================] - 0s 316ms/step
# [8] (92.90%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.0006477237
# filt453
# 1/1 [==============================] - 0s 322ms/step
# [8] (92.95%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  7.18832e-05
# filt454
# 1/1 [==============================] - 0s 317ms/step
# [8] (93.09%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0012974739
# filt455
# 1/1 [==============================] - 0s 318ms/step
# [8] (92.96%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  2.336502e-05
# filt456
# 1/1 [==============================] - 0s 310ms/step
# [8] (93.04%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0008060932
# filt457
# 1/1 [==============================] - 0s 308ms/step
# [8] (92.98%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00017082691
# filt458
# 1/1 [==============================] - 0s 310ms/step
# [8] (93.07%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0010443926
# filt459
# 1/1 [==============================] - 0s 314ms/step
# [8] (93.01%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0005213022
# filt460
# 1/1 [==============================] - 0s 321ms/step
# [8] (92.99%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00022888184
# filt461
# 1/1 [==============================] - 0s 329ms/step
# [8] (92.91%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.00052553415
# filt462
# 1/1 [==============================] - 0s 324ms/step
# [8] (93.06%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00094276667
# filt463
# 1/1 [==============================] - 0s 330ms/step
# [8] (93.08%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0011779666
# filt464
# 1/1 [==============================] - 0s 331ms/step
# [8] (93.05%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00089251995
# filt465
# 1/1 [==============================] - 0s 320ms/step
# [8] (92.86%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.0010014772
# filt466
# 1/1 [==============================] - 0s 340ms/step
# [8] (92.98%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00012910366
# filt467
# 1/1 [==============================] - 0s 349ms/step
# [8] (92.93%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.0003658533
# filt468
# 1/1 [==============================] - 0s 347ms/step
# [8] (93.08%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0011776686
# filt469
# 1/1 [==============================] - 0s 310ms/step
# [8] (92.91%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.00051933527
# filt470
# 1/1 [==============================] - 0s 325ms/step
# [8] (93.05%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0009111762
# filt471
# 1/1 [==============================] - 0s 316ms/step
# [8] (93.10%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0013732314
# filt472
# 1/1 [==============================] - 0s 313ms/step
# [8] (93.01%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00043308735
# filt473
# 1/1 [==============================] - 0s 315ms/step
# [8] (92.98%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00021225214
# filt474
# 1/1 [==============================] - 0s 312ms/step
# [8] (93.02%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0005379915
# filt475
# 1/1 [==============================] - 0s 331ms/step
# [8] (93.08%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0012162924
# filt476
# 1/1 [==============================] - 0s 320ms/step
# [8] (92.88%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.00078457594
# filt477
# 1/1 [==============================] - 0s 310ms/step
# [8] (93.23%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.002673328
# filt478
# 1/1 [==============================] - 0s 311ms/step
# [8] (93.12%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0016179681
# filt479
# 1/1 [==============================] - 0s 320ms/step
# [8] (93.13%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0016598701
# filt480
# 1/1 [==============================] - 0s 326ms/step
# [8] (93.11%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0015082955
# filt481
# 1/1 [==============================] - 0s 347ms/step
# [8] (93.14%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0017460585
# filt482
# 1/1 [==============================] - 0s 330ms/step
# [8] (93.11%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0014321208
# filt483
# 1/1 [==============================] - 0s 330ms/step
# [8] (93.05%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00086146593
# filt484
# 1/1 [==============================] - 0s 317ms/step
# [8] (93.02%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0006015301
# filt485
# 1/1 [==============================] - 0s 333ms/step
# [8] (92.81%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.0015227199
# filt486
# 1/1 [==============================] - 0s 343ms/step
# [8] (93.08%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0011990666
# filt487
# 1/1 [==============================] - 0s 326ms/step
# [8] (93.00%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00033599138
# filt488
# 1/1 [==============================] - 0s 326ms/step
# [8] (93.30%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0033857226
# filt489
# 1/1 [==============================] - 0s 324ms/step
# [8] (93.00%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0004028082
# filt490
# 1/1 [==============================] - 0s 308ms/step
# [8] (93.03%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00069242716
# filt491
# 1/1 [==============================] - 0s 312ms/step
# [8] (93.19%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0023216605
# filt492
# 1/1 [==============================] - 0s 310ms/step
# [8] (93.07%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0010914207
# filt493
# 1/1 [==============================] - 0s 319ms/step
# [8] (92.87%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.0008736253
# filt494
# 1/1 [==============================] - 0s 318ms/step
# [8] (93.04%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0007812381
# filt495
# 1/1 [==============================] - 0s 306ms/step
# [8] (93.00%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00034713745
# filt496
# 1/1 [==============================] - 0s 324ms/step
# [8] (93.20%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0023307204
# filt497
# 1/1 [==============================] - 0s 331ms/step
# [8] (93.01%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00043052435
# filt498
# 1/1 [==============================] - 0s 339ms/step
# [8] (93.16%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.001988113
# filt499
# 1/1 [==============================] - 0s 325ms/step
# [8] (93.03%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00070786476
# filt500
# 1/1 [==============================] - 0s 324ms/step
# [8] (93.13%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0016826987
# filt501
# 1/1 [==============================] - 0s 322ms/step
# [8] (92.92%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.0004518032
# filt502
# 1/1 [==============================] - 0s 322ms/step
# [8] (92.94%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.0002310276
# filt503
# 1/1 [==============================] - 0s 323ms/step
# [8] (93.06%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00095033646
# filt504
# 1/1 [==============================] - 0s 319ms/step
# [8] (93.10%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0014051795
# filt505
# 1/1 [==============================] - 0s 326ms/step
# [8] (93.05%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0008416176
# filt506
# 1/1 [==============================] - 0s 323ms/step
# [8] (93.00%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00039225817
# filt507
# 1/1 [==============================] - 0s 321ms/step
# [8] (93.18%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.002164781
# filt508
# 1/1 [==============================] - 0s 319ms/step
# [8] (93.07%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0010429025
# filt509
# 1/1 [==============================] - 0s 319ms/step
# [8] (93.02%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.00056636333
# filt510
# 1/1 [==============================] - 0s 306ms/step
# [8] (93.05%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  -0.0008685589
# filt511
# 1/1 [==============================] - 0s 320ms/step
# [8] (92.96%)
# [INFO] Predicted new: 8, Actual: 9
# difference:  0.0
# --- 603.3378219604492 seconds ---
# pair ley: {'9__139.png_as_8': [(394, (0.002888441, 1)), (130, (0.0024232864, 1)), (274, (0.0020911098, 1)), (434, (0.0018977523, 1)), (485, (0.0015227199, 1)), (170, (0.0014683604, 1)), (248, (0.0013228655, 1)), (100, (0.0012910962, 1)), (347, (0.0012648106, 1)), (285, (0.001237154, 1)), (332, (0.0012030602, 1)), (282, (0.0011662841, 1)), (341, (0.001132369, 1)), (139, (0.0011270046, 1)), (116, (0.0011262894, 1)), (162, (0.0011044145, 1)), (355, (0.0010732412, 1)), (98, (0.0010492802, 1)), (22, (0.0010185838, 1)), (465, (0.0010014772, 1)), (229, (0.0010000467, 1)), (314, (0.0009689331, 1)), (450, (0.00096452236, 1)), (442, (0.000944674, 1)), (422, (0.0009340644, 1)), (75, (0.00092417, 1)), (402, (0.0009177923, 1)), (237, (0.00090402365, 1)), (385, (0.0008983612, 1)), (278, (0.0008956194, 1)), (325, (0.00088459253, 1)), (493, (0.0008736253, 1)), (330, (0.000859499, 1)), (215, (0.0008556843, 1)), (345, (0.00083887577, 1)), (476, (0.00078457594, 1)), (372, (0.0007816553, 1)), (194, (0.00075399876, 1)), (224, (0.0007523298, 1)), (96, (0.0007442236, 1)), (452, (0.0006477237, 1)), (381, (0.00058561563, 1)), (377, (0.00058084726, 1)), (357, (0.0005463958, 1)), (192, (0.00053304434, 1)), (16, (0.0005275607, 1)), (461, (0.00052553415, 1)), (469, (0.00051933527, 1)), (112, (0.0005030632, 1)), (151, (0.0004605651, 1)), (501, (0.0004518032, 1)), (9, (0.00044637918, 1)), (166, (0.00044637918, 1)), (249, (0.00043678284, 1)), (293, (0.0004095435, 1)), (439, (0.00039935112, 1)), (263, (0.00039821863, 1)), (146, (0.0003887415, 1)), (236, (0.00037050247, 1)), (467, (0.0003658533, 1)), (80, (0.00036215782, 1)), (180, (0.0003504157, 1)), (189, (0.00034612417, 1)), (217, (0.0003412962, 1)), (74, (0.0003196597, 1)), (135, (0.00030505657, 1)), (12, (0.00030100346, 1)), (390, (0.00028938055, 1)), (252, (0.0002782941, 1)), (305, (0.00024396181, 1)), (367, (0.00023585558, 1)), (502, (0.0002310276, 1)), (120, (0.0001989007, 1)), (265, (0.00018107891, 1)), (164, (0.00017517805, 1)), (296, (0.00016653538, 1)), (308, (0.00016230345, 1)), (392, (0.00015616417, 1)), (342, (0.00014728308, 1)), (196, (0.00013893843, 1)), (50, (0.00013494492, 1)), (346, (0.0001335144, 1)), (219, (0.0001245141, 1)), (415, (0.00011843443, 1)), (117, (0.000113904476, 1)), (429, (0.00011318922, 1)), (25, (9.506941e-05, 1)), (382, (8.98242e-05, 1)), (31, (8.6188316e-05, 1)), (275, (8.529425e-05, 1)), (310, (7.9751015e-05, 1)), (160, (7.516146e-05, 1)), (453, (7.18832e-05, 1)), (416, (5.4597855e-05, 1)), (447, (5.3167343e-05, 1)), (175, (4.4822693e-05, 1)), (352, (4.273653e-05, 1)), (15, (3.2544136e-05, 1)), (323, (2.7060509e-05, 1)), (455, (2.336502e-05, 1)), (255, (2.2768974e-05, 1)), (54, (1.8537045e-05, 1)), (110, (1.3291836e-05, 1)), (216, (1.31726265e-05, 1)), (124, (6.377697e-06, 1)), (511, (0.0, 1)), (212, (-1.31726265e-05, 1)), (202, (-2.0742416e-05, 1)), (362, (-3.1232834e-05, 1)), (443, (-4.2378902e-05, 1)), (179, (-8.08835e-05, 1)), (427, (-9.2446804e-05, 1)), (384, (-0.00011229515, 1)), (406, (-0.00012457371, 1)), (466, (-0.00012910366, 1)), (344, (-0.0001295209, 1)), (231, (-0.00014805794, 1)), (30, (-0.00016331673, 1)), (253, (-0.00016510487, 1)), (457, (-0.00017082691, 1)), (71, (-0.00017875433, 1)), (287, (-0.00018364191, 1)), (234, (-0.00019711256, 1)), (51, (-0.00020486116, 1)), (473, (-0.00021225214, 1)), (40, (-0.0002168417, 1)), (360, (-0.00021970272, 1)), (460, (-0.00022888184, 1)), (312, (-0.00023889542, 1)), (38, (-0.00024080276, 1)), (28, (-0.00024217367, 1)), (358, (-0.00024276972, 1)), (90, (-0.00024348497, 1)), (334, (-0.0002513528, 1)), (108, (-0.00025618076, 1)), (81, (-0.00027483702, 1)), (361, (-0.00030434132, 1)), (335, (-0.00031608343, 1)), (61, (-0.00032442808, 1)), (65, (-0.0003272891, 1)), (173, (-0.00033032894, 1)), (393, (-0.0003311038, 1)), (167, (-0.000333488, 1)), (487, (-0.00033599138, 1)), (92, (-0.0003361702, 1)), (329, (-0.00033688545, 1)), (378, (-0.00034040213, 1)), (284, (-0.00034165382, 1)), (495, (-0.00034713745, 1)), (247, (-0.0003 ...
# imgPath :  PGD_10/9/1841.png
# 1/1 [==============================] - 0s 43ms/step
# [1] (84.08%)
# [INFO] Predicted: 1, Actual: 9
# filt0
# 1/1 [==============================] - 0s 321ms/step
# [1] (84.34%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.002575338
# filt1
# 1/1 [==============================] - 0s 324ms/step
# [1] (84.00%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00077295303
# filt2
# 1/1 [==============================] - 0s 336ms/step
# [1] (83.90%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0018258691
# filt3
# 1/1 [==============================] - 0s 321ms/step
# [1] (84.00%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00085157156
# filt4
# 1/1 [==============================] - 0s 323ms/step
# [1] (84.13%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0004962683
# filt5
# 1/1 [==============================] - 0s 342ms/step
# [1] (84.26%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0018117428
# filt6
# 1/1 [==============================] - 0s 328ms/step
# [1] (84.06%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00018072128
# filt7
# 1/1 [==============================] - 0s 326ms/step
# [1] (84.46%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0037652254
# filt8
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.16%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00082302094
# filt9
# 1/1 [==============================] - 0s 308ms/step
# [1] (84.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0013152957
# filt10
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.11%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00028824806
# filt11
# 1/1 [==============================] - 0s 317ms/step
# [1] (84.06%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00018376112
# filt12
# 1/1 [==============================] - 0s 328ms/step
# [1] (84.04%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0004080534
# filt13
# 1/1 [==============================] - 0s 316ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00090807676
# filt14
# 1/1 [==============================] - 0s 320ms/step
# [1] (84.13%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00046914816
# filt15
# 1/1 [==============================] - 0s 313ms/step
# [1] (84.07%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00015509129
# filt16
# 1/1 [==============================] - 0s 311ms/step
# [1] (84.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0007160902
# filt17
# 1/1 [==============================] - 0s 323ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00088763237
# filt18
# 1/1 [==============================] - 0s 352ms/step
# [1] (84.37%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0028989315
# filt19
# 1/1 [==============================] - 0s 350ms/step
# [1] (84.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0007055402
# filt20
# 1/1 [==============================] - 0s 329ms/step
# [1] (84.16%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0007879138
# filt21
# 1/1 [==============================] - 0s 315ms/step
# [1] (84.06%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00026267767
# filt22
# 1/1 [==============================] - 0s 320ms/step
# [1] (84.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0012955666
# filt23
# 1/1 [==============================] - 0s 323ms/step
# [1] (83.94%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.001410842
# filt24
# 1/1 [==============================] - 0s 315ms/step
# [1] (83.85%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0022755265
# filt25
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0013259649
# filt26
# 1/1 [==============================] - 0s 309ms/step
# [1] (84.10%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00022679567
# filt27
# 1/1 [==============================] - 0s 316ms/step
# [1] (84.03%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0005110502
# filt28
# 1/1 [==============================] - 0s 320ms/step
# [1] (84.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0013130903
# filt29
# 1/1 [==============================] - 0s 321ms/step
# [1] (84.18%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0009576678
# filt30
# 1/1 [==============================] - 0s 328ms/step
# [1] (84.11%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00026458502
# filt31
# 1/1 [==============================] - 0s 325ms/step
# [1] (84.61%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.005289495
# filt32
# 1/1 [==============================] - 0s 319ms/step
# [1] (83.99%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0008789301
# filt33
# 1/1 [==============================] - 0s 318ms/step
# [1] (84.02%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.000636816
# filt34
# 1/1 [==============================] - 0s 342ms/step
# [1] (84.00%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00084400177
# filt35
# 1/1 [==============================] - 0s 334ms/step
# [1] (84.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0006994605
# filt36
# 1/1 [==============================] - 0s 335ms/step
# [1] (84.05%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00032699108
# filt37
# 1/1 [==============================] - 0s 318ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00083738565
# filt38
# 1/1 [==============================] - 0s 316ms/step
# [1] (84.12%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0003412962
# filt39
# 1/1 [==============================] - 0s 313ms/step
# [1] (84.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0013116002
# filt40
# 1/1 [==============================] - 0s 341ms/step
# [1] (84.31%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.002268076
# filt41
# 1/1 [==============================] - 0s 323ms/step
# [1] (83.82%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0025728345
# filt42
# 1/1 [==============================] - 0s 326ms/step
# [1] (84.05%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00031739473
# filt43
# 1/1 [==============================] - 0s 307ms/step
# [1] (84.04%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00039166212
# filt44
# 1/1 [==============================] - 0s 315ms/step
# [1] (83.88%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0020502806
# filt45
# 1/1 [==============================] - 0s 311ms/step
# [1] (84.16%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00074756145
# filt46
# 1/1 [==============================] - 0s 312ms/step
# [1] (84.27%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0019071698
# filt47
# 1/1 [==============================] - 0s 312ms/step
# [1] (84.11%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0003170371
# filt48
# 1/1 [==============================] - 0s 315ms/step
# [1] (84.03%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00053209066
# filt49
# 1/1 [==============================] - 0s 317ms/step
# [1] (84.09%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -5.954504e-05
# filt50
# 1/1 [==============================] - 0s 320ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00083601475
# filt51
# 1/1 [==============================] - 0s 328ms/step
# [1] (84.06%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00020134449
# filt52
# 1/1 [==============================] - 0s 318ms/step
# [1] (84.20%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.001141429
# filt53
# 1/1 [==============================] - 0s 321ms/step
# [1] (84.05%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00031107664
# filt54
# 1/1 [==============================] - 0s 319ms/step
# [1] (83.91%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0017076731
# filt55
# 1/1 [==============================] - 0s 317ms/step
# [1] (84.11%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00029802322
# filt56
# 1/1 [==============================] - 0s 327ms/step
# [1] (84.22%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0013769269
# filt57
# 1/1 [==============================] - 0s 332ms/step
# [1] (84.61%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0052986145
# filt58
# 1/1 [==============================] - 0s 326ms/step
# [1] (84.06%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00018310547
# filt59
# 1/1 [==============================] - 0s 312ms/step
# [1] (84.14%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00057804585
# filt60
# 1/1 [==============================] - 0s 309ms/step
# [1] (84.05%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0003193617
# filt61
# 1/1 [==============================] - 0s 300ms/step
# [1] (84.19%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0011291504
# filt62
# 1/1 [==============================] - 0s 321ms/step
# [1] (84.59%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0050895214
# filt63
# 1/1 [==============================] - 0s 327ms/step
# [1] (84.03%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00048714876
# filt64
# 1/1 [==============================] - 0s 316ms/step
# [1] (84.14%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00053685904
# filt65
# 1/1 [==============================] - 0s 315ms/step
# [1] (84.23%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0015029907
# filt66
# 1/1 [==============================] - 0s 326ms/step
# [1] (84.48%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0039667487
# filt67
# 1/1 [==============================] - 0s 322ms/step
# [1] (84.13%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00048428774
# filt68
# 1/1 [==============================] - 0s 333ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00091803074
# filt69
# 1/1 [==============================] - 0s 324ms/step
# [1] (84.10%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0001513362
# filt70
# 1/1 [==============================] - 0s 343ms/step
# [1] (84.04%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0004117489
# filt71
# 1/1 [==============================] - 0s 363ms/step
# [1] (84.05%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00027877092
# filt72
# 1/1 [==============================] - 0s 493ms/step
# [1] (84.31%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.002243936
# filt73
# 1/1 [==============================] - 0s 354ms/step
# [1] (84.14%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0005506277
# filt74
# 1/1 [==============================] - 0s 319ms/step
# [1] (84.01%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00073724985
# filt75
# 1/1 [==============================] - 0s 315ms/step
# [1] (83.87%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0021008253
# filt76
# 1/1 [==============================] - 0s 311ms/step
# [1] (84.14%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.000536561
# filt77
# 1/1 [==============================] - 0s 306ms/step
# [1] (84.01%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0007302761
# filt78
# 1/1 [==============================] - 0s 301ms/step
# [1] (84.08%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -1.1146069e-05
# filt79
# 1/1 [==============================] - 0s 315ms/step
# [1] (84.01%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00076556206
# filt80
# 1/1 [==============================] - 0s 320ms/step
# [1] (84.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0012354255
# filt81
# 1/1 [==============================] - 0s 325ms/step
# [1] (84.00%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0008111596
# filt82
# 1/1 [==============================] - 0s 330ms/step
# [1] (84.29%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.002131164
# filt83
# 1/1 [==============================] - 0s 329ms/step
# [1] (84.52%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004358411
# filt84
# 1/1 [==============================] - 0s 331ms/step
# [1] (84.08%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  3.8981438e-05
# filt85
# 1/1 [==============================] - 0s 338ms/step
# [1] (84.38%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0029674172
# filt86
# 1/1 [==============================] - 0s 338ms/step
# [1] (83.80%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0028598905
# filt87
# 1/1 [==============================] - 0s 320ms/step
# [1] (84.07%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00012350082
# filt88
# 1/1 [==============================] - 0s 318ms/step
# [1] (84.11%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00024431944
# filt89
# 1/1 [==============================] - 0s 312ms/step
# [1] (83.86%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0022554994
# filt90
# 1/1 [==============================] - 0s 312ms/step
# [1] (83.99%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.000962317
# filt91
# 1/1 [==============================] - 0s 309ms/step
# [1] (84.16%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00075262785
# filt92
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.12%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00038862228
# filt93
# 1/1 [==============================] - 0s 308ms/step
# [1] (84.04%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00037425756
# filt94
# 1/1 [==============================] - 0s 315ms/step
# [1] (83.83%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0025491118
# filt95
# 1/1 [==============================] - 0s 343ms/step
# [1] (84.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0006427169
# filt96
# 1/1 [==============================] - 0s 317ms/step
# [1] (84.03%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00047159195
# filt97
# 1/1 [==============================] - 0s 305ms/step
# [1] (84.13%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0005056262
# filt98
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.16%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.000829041
# filt99
# 1/1 [==============================] - 0s 327ms/step
# [1] (84.12%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0003774166
# filt100
# 1/1 [==============================] - 0s 320ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0008456707
# filt101
# 1/1 [==============================] - 0s 318ms/step
# [1] (84.04%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00044322014
# filt102
# 1/1 [==============================] - 0s 335ms/step
# [1] (83.85%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.002340734
# filt103
# 1/1 [==============================] - 0s 319ms/step
# [1] (83.97%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0010923743
# filt104
# 1/1 [==============================] - 0s 339ms/step
# [1] (84.30%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0022176504
# filt105
# 1/1 [==============================] - 0s 322ms/step
# [1] (83.74%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0033994317
# filt106
# 1/1 [==============================] - 0s 350ms/step
# [1] (84.40%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.003228724
# filt107
# 1/1 [==============================] - 0s 329ms/step
# [1] (84.18%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0009599328
# filt108
# 1/1 [==============================] - 0s 336ms/step
# [1] (84.11%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00030738115
# filt109
# 1/1 [==============================] - 0s 320ms/step
# [1] (84.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0012741089
# filt110
# 1/1 [==============================] - 0s 326ms/step
# [1] (83.93%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.001490891
# filt111
# 1/1 [==============================] - 0s 310ms/step
# [1] (83.98%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0010101795
# filt112
# 1/1 [==============================] - 0s 315ms/step
# [1] (84.32%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0023354888
# filt113
# 1/1 [==============================] - 0s 312ms/step
# [1] (83.71%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.003715396
# filt114
# 1/1 [==============================] - 0s 306ms/step
# [1] (84.18%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00096958876
# filt115
# 1/1 [==============================] - 0s 308ms/step
# [1] (84.20%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0011736155
# filt116
# 1/1 [==============================] - 0s 319ms/step
# [1] (84.18%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0009692311
# filt117
# 1/1 [==============================] - 0s 340ms/step
# [1] (84.23%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0014654398
# filt118
# 1/1 [==============================] - 0s 326ms/step
# [1] (84.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0012490153
# filt119
# 1/1 [==============================] - 0s 319ms/step
# [1] (84.32%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0023456216
# filt120
# 1/1 [==============================] - 0s 323ms/step
# [1] (84.30%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0022064447
# filt121
# 1/1 [==============================] - 0s 320ms/step
# [1] (84.01%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00069612265
# filt122
# 1/1 [==============================] - 0s 328ms/step
# [1] (84.06%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00024467707
# filt123
# 1/1 [==============================] - 0s 334ms/step
# [1] (84.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0007033944
# filt124
# 1/1 [==============================] - 0s 319ms/step
# [1] (84.31%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0022389889
# filt125
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.51%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004282415
# filt126
# 1/1 [==============================] - 0s 307ms/step
# [1] (84.13%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0005004406
# filt127
# 1/1 [==============================] - 0s 320ms/step
# [1] (83.74%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0034646392
# filt128
# 1/1 [==============================] - 0s 319ms/step
# [1] (83.80%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0028378963
# filt129
# 1/1 [==============================] - 0s 332ms/step
# [1] (84.40%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0031388402
# filt130
# 1/1 [==============================] - 0s 327ms/step
# [1] (83.75%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0032730103
# filt131
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.01%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00071674585
# filt132
# 1/1 [==============================] - 0s 327ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00091165304
# filt133
# 1/1 [==============================] - 0s 324ms/step
# [1] (83.95%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0013219118
# filt134
# 1/1 [==============================] - 0s 341ms/step
# [1] (84.07%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00013637543
# filt135
# 1/1 [==============================] - 0s 331ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0008517504
# filt136
# 1/1 [==============================] - 0s 330ms/step
# [1] (84.04%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00045788288
# filt137
# 1/1 [==============================] - 0s 324ms/step
# [1] (84.01%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00067549944
# filt138
# 1/1 [==============================] - 0s 331ms/step
# [1] (84.18%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0009955168
# filt139
# 1/1 [==============================] - 0s 330ms/step
# [1] (84.02%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0006374717
# filt140
# 1/1 [==============================] - 0s 324ms/step
# [1] (84.19%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.001062274
# filt141
# 1/1 [==============================] - 0s 310ms/step
# [1] (83.89%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0019176602
# filt142
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.30%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0021952987
# filt143
# 1/1 [==============================] - 0s 310ms/step
# [1] (83.87%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0020956397
# filt144
# 1/1 [==============================] - 0s 311ms/step
# [1] (84.10%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00014448166
# filt145
# 1/1 [==============================] - 0s 299ms/step
# [1] (83.80%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0027913451
# filt146
# 1/1 [==============================] - 0s 310ms/step
# [1] (83.98%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0009894967
# filt147
# 1/1 [==============================] - 0s 316ms/step
# [1] (83.73%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0035055876
# filt148
# 1/1 [==============================] - 0s 321ms/step
# [1] (84.08%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  3.7252903e-05
# filt149
# 1/1 [==============================] - 0s 328ms/step
# [1] (84.04%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0003812313
# filt150
# 1/1 [==============================] - 0s 334ms/step
# [1] (84.06%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0002092123
# filt151
# 1/1 [==============================] - 0s 319ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0009050369
# filt152
# 1/1 [==============================] - 0s 307ms/step
# [1] (83.93%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0015676022
# filt153
# 1/1 [==============================] - 0s 329ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00089645386
# filt154
# 1/1 [==============================] - 0s 326ms/step
# [1] (84.10%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0001462102
# filt155
# 1/1 [==============================] - 0s 349ms/step
# [1] (83.68%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0040252805
# filt156
# 1/1 [==============================] - 0s 320ms/step
# [1] (83.58%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0050522685
# filt157
# 1/1 [==============================] - 0s 315ms/step
# [1] (84.13%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0004826784
# filt158
# 1/1 [==============================] - 0s 309ms/step
# [1] (84.12%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00037127733
# filt159
# 1/1 [==============================] - 0s 307ms/step
# [1] (84.01%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00072038174
# filt160
# 1/1 [==============================] - 0s 306ms/step
# [1] (84.36%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0027323365
# filt161
# 1/1 [==============================] - 0s 333ms/step
# [1] (83.94%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.001373291
# filt162
# 1/1 [==============================] - 0s 331ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0008404255
# filt163
# 1/1 [==============================] - 0s 322ms/step
# [1] (84.13%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00051659346
# filt164
# 1/1 [==============================] - 0s 317ms/step
# [1] (84.00%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0008531809
# filt165
# 1/1 [==============================] - 0s 318ms/step
# [1] (83.99%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0009047985
# filt166
# 1/1 [==============================] - 0s 311ms/step
# [1] (84.41%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0032433867
# filt167
# 1/1 [==============================] - 0s 312ms/step
# [1] (84.07%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00013428926
# filt168
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.19%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0010469556
# filt169
# 1/1 [==============================] - 0s 353ms/step
# [1] (84.06%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00024086237
# filt170
# 1/1 [==============================] - 0s 346ms/step
# [1] (83.68%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.004013598
# filt171
# 1/1 [==============================] - 0s 352ms/step
# [1] (84.01%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0007251501
# filt172
# 1/1 [==============================] - 0s 325ms/step
# [1] (84.23%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0014913678
# filt173
# 1/1 [==============================] - 0s 315ms/step
# [1] (83.88%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0020246506
# filt174
# 1/1 [==============================] - 0s 318ms/step
# [1] (84.04%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00044959784
# filt175
# 1/1 [==============================] - 0s 327ms/step
# [1] (84.42%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0033447146
# filt176
# 1/1 [==============================] - 0s 327ms/step
# [1] (84.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00069248676
# filt177
# 1/1 [==============================] - 0s 324ms/step
# [1] (84.53%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0044884086
# filt178
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.47%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0038654804
# filt179
# 1/1 [==============================] - 0s 316ms/step
# [1] (84.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00065404177
# filt180
# 1/1 [==============================] - 0s 319ms/step
# [1] (84.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00071144104
# filt181
# 1/1 [==============================] - 0s 316ms/step
# [1] (84.11%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00024586916
# filt182
# 1/1 [==============================] - 0s 333ms/step
# [1] (83.79%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.002914548
# filt183
# 1/1 [==============================] - 0s 348ms/step
# [1] (83.88%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0020250678
# filt184
# 1/1 [==============================] - 0s 332ms/step
# [1] (84.24%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0015473962
# filt185
# 1/1 [==============================] - 0s 326ms/step
# [1] (84.01%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00068587065
# filt186
# 1/1 [==============================] - 0s 332ms/step
# [1] (84.14%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00055098534
# filt187
# 1/1 [==============================] - 0s 309ms/step
# [1] (84.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0013235211
# filt188
# 1/1 [==============================] - 0s 309ms/step
# [1] (84.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.000916183
# filt189
# 1/1 [==============================] - 0s 311ms/step
# [1] (83.75%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.003340602
# filt190
# 1/1 [==============================] - 0s 310ms/step
# [1] (84.14%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0005477667
# filt191
# 1/1 [==============================] - 0s 313ms/step
# [1] (84.16%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0008196831
# filt192
# 1/1 [==============================] - 0s 321ms/step
# [1] (83.96%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0012187362
# filt193
# 1/1 [==============================] - 0s 313ms/step
# [1] (83.98%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0009899139
# filt194
# 1/1 [==============================] - 0s 328ms/step
# [1] (83.85%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.002315104
# filt195
# 1/1 [==============================] - 0s 316ms/step
# [1] (84.39%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.003090322
# filt196
# 1/1 [==============================] - 0s 325ms/step
# [1] (84.09%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -5.2034855e-05
# filt197
# 1/1 [==============================] - 0s 326ms/step
# [1] (84.00%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00077050924
# filt198
# 1/1 [==============================] - 0s 324ms/step
# [1] (84.41%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0032718778
# filt199
# 1/1 [==============================] - 0s 339ms/step
# [1] (83.81%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0027043223
# filt200
# 1/1 [==============================] - 0s 333ms/step
# [1] (83.87%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0020769238
# filt201
# 1/1 [==============================] - 0s 330ms/step
# [1] (84.34%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0026160479
# filt202
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.09%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00013184547
# filt203
# 1/1 [==============================] - 0s 302ms/step
# [1] (84.08%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  6.556511e-05
# filt204
# 1/1 [==============================] - 0s 315ms/step
# [1] (84.26%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0018255711
# filt205
# 1/1 [==============================] - 0s 324ms/step
# [1] (84.43%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0035015345
# filt206
# 1/1 [==============================] - 0s 321ms/step
# [1] (84.11%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00031501055
# filt207
# 1/1 [==============================] - 0s 321ms/step
# [1] (84.10%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00022137165
# filt208
# 1/1 [==============================] - 0s 325ms/step
# [1] (83.94%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0014396906
# filt209
# 1/1 [==============================] - 0s 311ms/step
# [1] (84.00%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00081682205
# filt210
# 1/1 [==============================] - 0s 309ms/step
# [1] (84.19%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0010338426
# filt211
# 1/1 [==============================] - 0s 318ms/step
# [1] (84.22%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0014280677
# filt212
# 1/1 [==============================] - 0s 324ms/step
# [1] (84.42%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0033448935
# filt213
# 1/1 [==============================] - 0s 325ms/step
# [1] (84.25%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0016510487
# filt214
# 1/1 [==============================] - 0s 336ms/step
# [1] (84.16%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0007997155
# filt215
# 1/1 [==============================] - 0s 496ms/step
# [1] (84.02%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00064074993
# filt216
# 1/1 [==============================] - 0s 353ms/step
# [1] (84.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00073057413
# filt217
# 1/1 [==============================] - 0s 325ms/step
# [1] (84.09%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00010418892
# filt218
# 1/1 [==============================] - 0s 320ms/step
# [1] (83.84%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.002398312
# filt219
# 1/1 [==============================] - 0s 311ms/step
# [1] (84.25%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0017265081
# filt220
# 1/1 [==============================] - 0s 318ms/step
# [1] (84.20%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0012274384
# filt221
# 1/1 [==============================] - 0s 309ms/step
# [1] (83.82%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0025980473
# filt222
# 1/1 [==============================] - 0s 305ms/step
# [1] (83.88%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.002058804
# filt223
# 1/1 [==============================] - 0s 314ms/step
# [1] (84.09%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -5.799532e-05
# filt224
# 1/1 [==============================] - 0s 315ms/step
# [1] (84.18%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0009647012
# filt225
# 1/1 [==============================] - 0s 313ms/step
# [1] (83.94%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0014282465
# filt226
# 1/1 [==============================] - 0s 329ms/step
# [1] (83.93%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0015118718
# filt227
# 1/1 [==============================] - 0s 328ms/step
# [1] (84.13%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00047510862
# filt228
# 1/1 [==============================] - 0s 326ms/step
# [1] (84.02%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00064629316
# filt229
# 1/1 [==============================] - 0s 309ms/step
# [1] (84.12%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00033396482
# filt230
# 1/1 [==============================] - 0s 328ms/step
# [1] (84.07%)
# [INFO] Predicted new: 1, Actual: 9
# ...
# [1] (61.22%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0006135702
# filt292
# 1/1 [==============================] - 0s 311ms/step
# [1] (61.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00011831522
# filt293
# 1/1 [==============================] - 0s 309ms/step
# [1] (61.65%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0049230456
# filt294
# 1/1 [==============================] - 0s 313ms/step
# [1] (60.93%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0022491217
# filt295
# 1/1 [==============================] - 0s 324ms/step
# [1] (61.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00015079975
# filt296
# 1/1 [==============================] - 0s 332ms/step
# [1] (61.30%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0014610887
# filt297
# 1/1 [==============================] - 0s 333ms/step
# [1] (61.59%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004316151
# filt298
# 1/1 [==============================] - 0s 321ms/step
# [1] (61.35%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0018798709
# filt299
# 1/1 [==============================] - 0s 350ms/step
# [1] (61.42%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0026275516
# filt300
# 1/1 [==============================] - 0s 320ms/step
# [1] (61.57%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0040940046
# filt301
# 1/1 [==============================] - 0s 321ms/step
# [1] (61.89%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0073387027
# filt302
# 1/1 [==============================] - 0s 321ms/step
# [1] (61.48%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0032612681
# filt303
# 1/1 [==============================] - 0s 333ms/step
# [1] (61.31%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0015540123
# filt304
# 1/1 [==============================] - 0s 314ms/step
# [1] (60.84%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0031363368
# filt305
# 1/1 [==============================] - 0s 313ms/step
# [1] (61.24%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0008171797
# filt306
# 1/1 [==============================] - 0s 315ms/step
# [1] (61.45%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.002910614
# filt307
# 1/1 [==============================] - 0s 315ms/step
# [1] (61.06%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0009223819
# filt308
# 1/1 [==============================] - 0s 304ms/step
# [1] (61.33%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0017117858
# filt309
# 1/1 [==============================] - 0s 325ms/step
# [1] (61.40%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0024360418
# filt310
# 1/1 [==============================] - 0s 343ms/step
# [1] (61.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0004963875
# filt311
# 1/1 [==============================] - 0s 329ms/step
# [1] (61.75%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.005890906
# filt312
# 1/1 [==============================] - 0s 330ms/step
# [1] (61.49%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0033279061
# filt313
# 1/1 [==============================] - 0s 307ms/step
# [1] (61.32%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0016499758
# filt314
# 1/1 [==============================] - 0s 318ms/step
# [1] (61.41%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0024855733
# filt315
# 1/1 [==============================] - 0s 333ms/step
# [1] (61.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  7.82609e-05
# filt316
# 1/1 [==============================] - 0s 311ms/step
# [1] (61.29%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0013707876
# filt317
# 1/1 [==============================] - 0s 313ms/step
# [1] (61.24%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00081807375
# filt318
# 1/1 [==============================] - 0s 327ms/step
# [1] (61.33%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0017174482
# filt319
# 1/1 [==============================] - 0s 318ms/step
# [1] (61.55%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0038934946
# filt320
# 1/1 [==============================] - 0s 314ms/step
# [1] (61.40%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.002444446
# filt321
# 1/1 [==============================] - 0s 330ms/step
# [1] (61.29%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.001298368
# filt322
# 1/1 [==============================] - 0s 331ms/step
# [1] (61.71%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.005520165
# filt323
# 1/1 [==============================] - 0s 314ms/step
# [1] (61.95%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.007909298
# filt324
# 1/1 [==============================] - 0s 330ms/step
# [1] (61.18%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00020486116
# filt325
# 1/1 [==============================] - 0s 339ms/step
# [1] (61.48%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00323236
# filt326
# 1/1 [==============================] - 0s 329ms/step
# [1] (61.58%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0042583942
# filt327
# 1/1 [==============================] - 0s 326ms/step
# [1] (61.71%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.005515158
# filt328
# 1/1 [==============================] - 0s 318ms/step
# [1] (61.25%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0009507537
# filt329
# 1/1 [==============================] - 0s 320ms/step
# [1] (61.13%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00030100346
# filt330
# 1/1 [==============================] - 0s 321ms/step
# [1] (61.16%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -2.0503998e-05
# filt331
# 1/1 [==============================] - 0s 307ms/step
# [1] (61.35%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0018969178
# filt332
# 1/1 [==============================] - 0s 330ms/step
# [1] (61.30%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0014014244
# filt333
# 1/1 [==============================] - 0s 329ms/step
# [1] (61.31%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00148803
# filt334
# 1/1 [==============================] - 0s 312ms/step
# [1] (61.28%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.001219809
# filt335
# 1/1 [==============================] - 0s 329ms/step
# [1] (61.17%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -8.2194805e-05
# filt336
# 1/1 [==============================] - 0s 324ms/step
# [1] (61.34%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0018230677
# filt337
# 1/1 [==============================] - 0s 312ms/step
# [1] (61.57%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004103303
# filt338
# 1/1 [==============================] - 0s 320ms/step
# [1] (61.54%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0038496256
# filt339
# 1/1 [==============================] - 0s 322ms/step
# [1] (61.75%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.005970001
# filt340
# 1/1 [==============================] - 0s 325ms/step
# [1] (61.44%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0028179884
# filt341
# 1/1 [==============================] - 0s 316ms/step
# [1] (61.42%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.002645731
# filt342
# 1/1 [==============================] - 0s 329ms/step
# [1] (61.60%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004394114
# filt343
# 1/1 [==============================] - 0s 313ms/step
# [1] (61.47%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.003096044
# filt344
# 1/1 [==============================] - 0s 325ms/step
# [1] (61.03%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0012597442
# filt345
# 1/1 [==============================] - 0s 309ms/step
# [1] (61.39%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0023035407
# filt346
# 1/1 [==============================] - 0s 314ms/step
# [1] (61.42%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.002649963
# filt347
# 1/1 [==============================] - 0s 310ms/step
# [1] (61.55%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0039408803
# filt348
# 1/1 [==============================] - 0s 318ms/step
# [1] (61.25%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0009782314
# filt349
# 1/1 [==============================] - 0s 327ms/step
# [1] (61.41%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0025446415
# filt350
# 1/1 [==============================] - 0s 332ms/step
# [1] (61.41%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0025225878
# filt351
# 1/1 [==============================] - 0s 322ms/step
# [1] (60.93%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0023094416
# filt352
# 1/1 [==============================] - 0s 314ms/step
# [1] (61.07%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0008209348
# filt353
# 1/1 [==============================] - 0s 316ms/step
# [1] (61.65%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004918933
# filt354
# 1/1 [==============================] - 0s 328ms/step
# [1] (61.32%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0016524196
# filt355
# 1/1 [==============================] - 0s 326ms/step
# [1] (61.14%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00016957521
# filt356
# 1/1 [==============================] - 0s 334ms/step
# [1] (61.59%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00436002
# filt357
# 1/1 [==============================] - 0s 317ms/step
# [1] (61.43%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0027367473
# filt358
# 1/1 [==============================] - 0s 312ms/step
# [1] (61.50%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0033889413
# filt359
# 1/1 [==============================] - 0s 310ms/step
# [1] (61.87%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.007129073
# filt360
# 1/1 [==============================] - 0s 311ms/step
# [1] (61.40%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0024647713
# filt361
# 1/1 [==============================] - 0s 312ms/step
# [1] (61.66%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0050105453
# filt362
# 1/1 [==============================] - 0s 314ms/step
# [1] (61.04%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0011940002
# filt363
# 1/1 [==============================] - 0s 322ms/step
# [1] (61.22%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00059860945
# filt364
# 1/1 [==============================] - 0s 333ms/step
# [1] (61.61%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004494667
# filt365
# 1/1 [==============================] - 0s 332ms/step
# [1] (61.36%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0020464659
# filt366
# 1/1 [==============================] - 0s 327ms/step
# [1] (61.56%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0039964914
# filt367
# 1/1 [==============================] - 0s 330ms/step
# [1] (61.47%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.003171742
# filt368
# 1/1 [==============================] - 0s 347ms/step
# [1] (61.36%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.002004981
# filt369
# 1/1 [==============================] - 0s 339ms/step
# [1] (61.74%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.005823016
# filt370
# 1/1 [==============================] - 0s 337ms/step
# [1] (61.64%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0047876835
# filt371
# 1/1 [==============================] - 0s 319ms/step
# [1] (61.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00050771236
# filt372
# 1/1 [==============================] - 0s 313ms/step
# [1] (61.06%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0009807944
# filt373
# 1/1 [==============================] - 0s 315ms/step
# [1] (61.33%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0017374158
# filt374
# 1/1 [==============================] - 0s 308ms/step
# [1] (61.21%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00057822466
# filt375
# 1/1 [==============================] - 0s 305ms/step
# [1] (61.51%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.003533721
# filt376
# 1/1 [==============================] - 0s 329ms/step
# [1] (61.61%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0045324564
# filt377
# 1/1 [==============================] - 0s 365ms/step
# [1] (61.61%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0045050383
# filt378
# 1/1 [==============================] - 0s 335ms/step
# [1] (61.59%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004306078
# filt379
# 1/1 [==============================] - 0s 320ms/step
# [1] (61.53%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0037592053
# filt380
# 1/1 [==============================] - 0s 332ms/step
# [1] (61.29%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.001332581
# filt381
# 1/1 [==============================] - 0s 316ms/step
# [1] (61.56%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004040897
# filt382
# 1/1 [==============================] - 0s 337ms/step
# [1] (61.45%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0029138327
# filt383
# 1/1 [==============================] - 0s 327ms/step
# [1] (61.83%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.006758094
# filt384
# 1/1 [==============================] - 0s 318ms/step
# [1] (61.44%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0028059483
# filt385
# 1/1 [==============================] - 0s 328ms/step
# [1] (61.45%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0029568672
# filt386
# 1/1 [==============================] - 0s 319ms/step
# [1] (61.26%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0010254979
# filt387
# 1/1 [==============================] - 0s 336ms/step
# [1] (61.40%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0024095178
# filt388
# 1/1 [==============================] - 0s 333ms/step
# [1] (61.57%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004090488
# filt389
# 1/1 [==============================] - 0s 316ms/step
# [1] (61.31%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.001493752
# filt390
# 1/1 [==============================] - 0s 319ms/step
# [1] (61.57%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.004118681
# filt391
# 1/1 [==============================] - 0s 323ms/step
# [1] (61.43%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.002698958
# filt392
# 1/1 [==============================] - 0s 334ms/step
# [1] (61.00%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.0015714169
# filt393
# 1/1 [==============================] - 0s 348ms/step
# [1] (61.09%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00070244074
# filt394
# 1/1 [==============================] - 0s 329ms/step
# [1] (61.49%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0032810569
# filt395
# 1/1 [==============================] - 0s 330ms/step
# [1] (61.40%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0024006367
# filt396
# 1/1 [==============================] - 0s 324ms/step
# [1] (61.50%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0033947825
# filt397
# 1/1 [==============================] - 0s 325ms/step
# [1] (61.44%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0027876496
# filt398
# 1/1 [==============================] - 0s 323ms/step
# [1] (61.36%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0020397305
# filt399
# 1/1 [==============================] - 0s 332ms/step
# [1] (61.00%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00157547
# filt400
# 1/1 [==============================] - 0s 329ms/step
# [1] (61.45%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.00295192
# filt401
# 1/1 [==============================] - 0s 311ms/step
# [1] (61.46%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0030690432
# filt402
# 1/1 [==============================] - 0s 313ms/step
# [1] (61.36%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0020424724
# filt403
# 1/1 [==============================] - 0s 317ms/step
# [1] (61.32%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0016387701
# filt404
# 1/1 [==============================] - 0s 315ms/step
# [1] (61.35%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.001947701
# filt405
# 1/1 [==============================] - 0s 326ms/step
# [1] (61.62%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0045998096
# filt406
# 1/1 [==============================] - 0s 320ms/step
# [1] (61.15%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  6.1929226e-05
# filt407
# 1/1 [==============================] - 0s 322ms/step
# [1] (61.07%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  0.00082969666
# filt408
# 1/1 [==============================] - 0s 336ms/step
# [1] (61.33%)
# [INFO] Predicted new: 1, Actual: 9
# difference:  -0.0017194152
# filt409
